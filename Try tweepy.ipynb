# %%
import os
os.environ['TWITTER_CONSUMER_KEY']='nfcNu5mb925cpERcbQbpGWxsi'
os.environ['TWITTER_CONSUMER_SECRET']='DSn9hWFZM79nmAovlNGFV2mg29O3WRlxPNggMM9GcYh3uNT6eP'
os.environ['TWITTER_ACCESS_TOKEN']='292908760-wGSl6T8euoKJ0NHda9FLGLkaOUnq8vRxFnXRQK6u'
os.environ['TWITTER_ACCESS_TOKEN_SECRET']='sIgDEnXMP11b0u5QlT37gTJOoNvyRgdbI2A5lKpzOFw16'

# %%
import tweepy  # Manage Twitter API
import pandas as pd  # to create dataframes
import json
from os import environ  # To get the environment variables

# %%
auth = tweepy.OAuthHandler(environ['TWITTER_CONSUMER_KEY'],
                           environ['TWITTER_CONSUMER_SECRET'])

auth.set_access_token(environ['TWITTER_ACCESS_TOKEN'],
                      environ['TWITTER_ACCESS_TOKEN_SECRET'])

api = tweepy.API(auth_handler=auth, wait_on_rate_limit_notify=True,
                 wait_on_rate_limit=True)

# %%
consumer_key = 'nfcNu5mb925cpERcbQbpGWxsi'
consumer_secret = 'DSn9hWFZM79nmAovlNGFV2mg29O3WRlxPNggMM9GcYh3uNT6eP'

# We also need some tokens provided by twitter

access_token = '292908760-wGSl6T8euoKJ0NHda9FLGLkaOUnq8vRxFnXRQK6u'
access_token_secret = 'sIgDEnXMP11b0u5QlT37gTJOoNvyRgdbI2A5lKpzOFw16'

# Create a instance of OAuth
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.secure = True
auth.set_access_token(access_token, access_token_secret)

# If authorized, we can now load the API
api = tweepy.API(auth)
print ("Autenticación correcta!")
# Out:
# Autenticación correcta!

# %%
def get_timeline_data():

    tweets_list = []
    # construct the dataframe
    for tweet in tweepy.Cursor(api.user_timeline, include_rts=True).items():

        tweets_list.append([str(tweet.id), int(tweet._json['favorite_count']),
                            str(tweet._json['retweet_count']), tweet.created_at])

    tweets = pd.DataFrame(data=tweets_list,
                          columns=['id', 'like', 'retweet', 'date'])

    return tweets

# %%
tweets=get_timeline_data()

# %%
type(tweets)
# Out:
# pandas.core.frame.DataFrame

# %%
tweets.describe()
# Out:
#              like
# count  210.000000
# mean     0.033333
# std      0.265808
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      3.000000

# %%
import json
def process_or_store(tweet):
    print(json.dumps(tweet))

# %%
for status in tweepy.Cursor(api.home_timeline).items():
    # Process a single status
    # print(status.id,' ',status.user,' ',status.text)
    process_or_store(status._json)
# Out:
# {"created_at": "Sun Jan 20 09:27:21 +0000 2019", "id": 1086918092578582528, "id_str": "1086918092578582528", "text": "RT @Ricardolau: RT @andres7ll: Que pena no haberlo le\u00eddo antes. Librazo!! @pablogonzalezpe @0xWORD https://t.co/Kyndb9lLjO", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "Ricardolau", "name": "Ricardo", "id": 51063430, "id_str": "51063430", "indices": [3, 14]}, {"screen_name": "andres7ll", "name": "Andr\u00e9s Siete", "id": 1150969963, "id_str": "1150969963", "indices": [19, 29]}, {"screen_name": "pablogonzalezpe", "name": "Pablo Gonz\u00e1lez", "id": 1478269165, "id_str": "1478269165", "indices": [74, 90]}, {"screen_name": "0xWORD", "name": "0xWORD", "id": 1378933351, "id_str": "1378933351", "indices": [91, 98]}], "urls": [], "media": [{"id": 1086267752036384768, "id_str": "1086267752036384768", "indices": [99, 122], "media_url": "http://pbs.twimg.com/media/DxMyw-MXQAAkj3f.jpg", "media_url_https": "https://pbs
# ...

# %%
type(status)
# Out:
# tweepy.models.Status

# %%
dir(status)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'possibly_sensitive_appealable',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
# ...
